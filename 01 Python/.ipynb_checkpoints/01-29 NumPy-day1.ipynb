# %%
import numpy as np

# %%
l = [1,2,3,4,4]

# %%
type(l)
# Out:
# list

# %%
a = np.array(l)

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a
# Out:
# array([1, 2, 3, 4, 4])

# %%
a1 = np.array([[1,2,3],[3,4,5,5]])
# Out:
# C:\Users\Praveen.Rajendhiran\AppData\Local\Temp\ipykernel_42688\82492600.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   a1 = np.array([[1,2,3],[3,4,5,5]])

# %%
a1 = np.array([[1,2,3],[3,4,5]])
a1
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %%
a2 = np.array([[[1,2,3],
                [4,5,6]]])
a2
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]]])

# %%
print (a.ndim)
print (a1.ndim)
print (a2.ndim)
# Out:
# 1
# 2
# 3

# %%
a3 = np.array([[[1,2,3], [4,5,6]], [[1,2,3], [4,5,6]], [[1,2,3], [4,5,6]]])
a3
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
a3.ndim
# Out:
# 3

# %%
a4 = np.array([[[[1,2,3], [4,5,6]], [[1,2,3], [4,5,6]], [[1,2,3], [4,5,6]]]])
a4
# Out:
# array([[[[1, 2, 3],
#          [4, 5, 6]],
#
#         [[1, 2, 3],
#          [4, 5, 6]],
#
#         [[1, 2, 3],
#          [4, 5, 6]]]])

# %%
a4.ndim
# Out:
# 4

# %%
a1 = a
print (a1)
print (a)
# Out:
# [1 2 3 4 4]
# [1 2 3 4 4]

# %%
a[0] = 10

# %%
print (a1)
print (a)
# Out:
# [10  2  3 50  4]
# [10  2  3 50  4]

# %%
a1[3] = 50

# %% [markdown]
# Shallow vs Deep copy

# %% [markdown]
# https://stackoverflow.com/questions/184710/what-is-the-difference-between-a-deep-copy-and-a-shallow-copy

# %%
a2 = np.copy(a)

# %%
print (a2)
print (a)
# Out:
# [10  2  3 50  4]
# [10  2  3 50  4]

# %%
a2[2] = 30
print (a2)
print (a)
# Out:
# [10  2 30 50  4]
# [10  2  3 50  4]

# %%
# generate data for numpy arrays
np.fromfunction(lambda i,j : i==j, (3,4))
# Out:
# array([[ True, False, False, False],
#        [False,  True, False, False],
#        [False, False,  True, False]])

# %%
np.fromfunction(lambda i,j : i==j, (3,4))

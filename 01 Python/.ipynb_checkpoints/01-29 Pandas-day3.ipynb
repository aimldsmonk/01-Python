# %%
d2 = {'key1':[6,7,8,9,10,"sudh"],
      'key2':[16,17,18,19,20,"prav"],
      'key3':[26,27,28,29,30,"gok"],
      'key4':[36,37,38,39,40,"dinesh"],
      }

# %%
d1 = {'key1':[1,2,3,4,5,"sudh1"],
      'key2':[1,2,3,4,5,"sudh2"],
      'key3':[1,2,3,4,5,"sudh3"],
      'key10':[36,37,38,39,40,"sudh4"]}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(d1)
df2 = pd.DataFrame(d2)

# %%
pd.merge(df1, df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=0'>1</a> pd.merge(df1, df2)
#
# NameError: name 'pd' is not defined

# %%
pd.merge(df1, df2,how='inner',on='key4')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=0'>1</a> pd.merge(df1, df2,how='inner',on='key4')
#
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1110, in _MergeOperation._get_merge_keys(self)
#    1108     right_keys.append(rk)
#    1109 if lk is not None:
# -> 1110     left_keys.append(left._get_label_or_level_values(lk))
#    1111     join_names.append(lk)
#    1112 else:
#    1113     # work-around for merge_asof(left_index=True)
#
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'key4'

# %%
import pandas as pd

# %%
k1 = {'key1':[20,30,"sudh1"],
      'key2':[20,30,"sudh2"],
      'key3':[30,40,"sudh3"] }

k2 = {'key1':[50,30,"sudh1"],
      'key2':[100,30,"sudh2"],
      'key3':[30,40,"sudh3"] }

df1 = pd.DataFrame(k1)
df2 = pd.DataFrame(k2)

# %%
df2
# Out:
#     key1   key2   key3
# 0     50    100     30
# 1     30     30     40
# 2  sudh1  sudh2  sudh3

# %%
df1
# Out:
#     key1   key2   key3
# 0     20     20     30
# 1     30     30     40
# 2  sudh1  sudh2  sudh3

# %%
pd.merge(df1, df2,how = 'left', on='key1')
# Out:
#     key1 key2_x key3_x key2_y key3_y
# 0     20     20     30    NaN    NaN
# 1     30     30     40     30     40
# 2  sudh1  sudh2  sudh3  sudh2  sudh3

# %%
d10 = {'key11':[1,2,3,4,5,"sudh"],
       'key22':[7,8,9,10,11,12],
       'key31':[13,14,15,16,17,18],
       'key41':[19,20,21,22,23,24]
       }

df10 = pd.DataFrame(d10, index = [1,2,3,4,5,6])

d20 = {'key1':[1,2,3,4,5,"sudh"],
       'key2':[7,8,"kumar",10,11,12],
       'key3':[13,14,15,16,17,18],
       'key4':[19,20,21,"ineuron","pwskills",24]
       }

df20 = pd.DataFrame(d20, index = [1,2,3,4,5,'sudh'])

# %%
# joins based on indexes
# merge based on column values

df10.join(df20)
# Out:
#   key11  key22  key31  key41 key1   key2  key3      key4
# 1     1      7     13     19    1      7  13.0        19
# 2     2      8     14     20    2      8  14.0        20
# 3     3      9     15     21    3  kumar  15.0        21
# 4     4     10     16     22    4     10  16.0   ineuron
# 5     5     11     17     23    5     11  17.0  pwskills
# 6  sudh     12     18     24  NaN    NaN   NaN       NaN

# %%
df10.join(df20,how= 'outer')
# Out:
#   key11  key22  key31  key41  key1   key2  key3      key4
# 1     1      7     13     19     1      7    13        19
# 2     2      8     14     20     2      8    14        20
# 3     3      9     15     21     3  kumar    15        21
# 4     4     10     16     22     4     10    16   ineuron
# 5     5     11     17     23     5     11    17  pwskills
# 6  sudh     12     18     24  sudh     12    18        24

# %%
# join matches based on the index
df10.join(df20,how= 'right')
# Out:
#      key11  key22  key31  key41  key1   key2  key3      key4
# 1        1    7.0   13.0   19.0     1      7    13        19
# 2        2    8.0   14.0   20.0     2      8    14        20
# 3        3    9.0   15.0   21.0     3  kumar    15        21
# 4        4   10.0   16.0   22.0     4     10    16   ineuron
# 5        5   11.0   17.0   23.0     5     11    17  pwskills
# sudh   NaN    NaN    NaN    NaN  sudh     12    18        24

# %%
df10.join(df20,how= 'left')
# Out:
#   key11  key22  key31  key41  key1   key2  key3      key4
# 1     1      7     13     19     1      7    13        19
# 2     2      8     14     20     2      8    14        20
# 3     3      9     15     21     3  kumar    15        21
# 4     4     10     16     22     4     10    16   ineuron
# 5     5     11     17     23     5     11    17  pwskills
# 6  sudh     12     18     24  sudh     12    18        24

# %%
df10.join(df20,how= 'inner')
# Out:
#   key11  key22  key31  key41  key1   key2  key3      key4
# 1     1      7     13     19     1      7    13        19
# 2     2      8     14     20     2      8    14        20
# 3     3      9     15     21     3  kumar    15        21
# 4     4     10     16     22     4     10    16   ineuron
# 5     5     11     17     23     5     11    17  pwskills
# 6  sudh     12     18     24  sudh     12    18        24

# %%
import pandas as pd
pd.concat([df10,df20],axis=0)
# Out:
#      key11  key22  key31  key41  key1   key2  key3      key4
# 1        1    7.0   13.0   19.0   NaN    NaN   NaN       NaN
# 2        2    8.0   14.0   20.0   NaN    NaN   NaN       NaN
# 3        3    9.0   15.0   21.0   NaN    NaN   NaN       NaN
# 4        4   10.0   16.0   22.0   NaN    NaN   NaN       NaN
# 5        5   11.0   17.0   23.0   NaN    NaN   NaN       NaN
# 6     sudh   12.0   18.0   24.0   NaN    NaN   NaN       NaN
# 1      NaN    NaN    NaN    NaN     1      7  13.0        19
# 2      NaN    NaN    NaN    NaN     2      8  14.0        20
# 3      NaN    NaN    NaN    NaN     3  kumar  15.0        21
# 4      NaN    NaN    NaN    NaN     4     10  16.0   ineuron
# 5      NaN    NaN    NaN    NaN     5     11  17.0  pwskills
# sudh   NaN    NaN    NaN    NaN  sudh     12  18.0        24

# %%
pd.concat([df10,df20],axis=1)
# Out:
#      key11  key22  key31  key41  key1   key2  key3      key4
# 1        1    7.0   13.0   19.0     1      7  13.0        19
# 2        2    8.0   14.0   20.0     2      8  14.0        20
# 3        3    9.0   15.0   21.0     3  kumar  15.0        21
# 4        4   10.0   16.0   22.0     4     10  16.0   ineuron
# 5        5   11.0   17.0   23.0     5     11  17.0  pwskills
# 6     sudh   12.0   18.0   24.0   NaN    NaN   NaN       NaN
# sudh   NaN    NaN    NaN    NaN  sudh     12  18.0        24

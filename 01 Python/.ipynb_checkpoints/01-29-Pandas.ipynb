# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.describe()
# mean - 
# standard - distance from mean - 1 sigma, 2 sigm, 3 sigma
# percentile - sorted in ascending order 
# th percentile - is an index.
# description works only on numerical values and not on strings or objects
# interquartile range
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# description works only on numerical values and not on strings or objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# filter out data type is object
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data[['Name','Sex','Ticket']].describe()
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# series
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
data.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
[data.dtypes[data.dtypes == "object"].index]
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == "object"].index]
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()

# %%
data[(data['Survived']==0) & (data['Sex']=='male')].describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   468.000000     468.0  468.000000  360.000000  468.000000  468.000000
# mean    449.121795       0.0    2.476496   31.618056    0.440171    0.207265
# std     260.365260       0.0    0.761411   14.056019    1.138507    0.601382
# min       1.000000       0.0    1.000000    1.000000    0.000000    0.000000
# 25%     212.500000       0.0    2.000000   21.750000    0.000000    0.000000
# 50%     461.000000       0.0    3.000000   29.000000    0.000000    0.000000
# 75%     678.500000       0.0    3.000000   39.250000    0.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    8.000000    5.000000
#
#              Fare
# count  468.000000
# mean    21.960993
# std     32.409799
# min      0.000000
# 25%      7.795800
# 50%      9.416650
# 75%     26.000000
# max    263.000000

# %%
# get a count
data[(data['Survived']==0) & (data['Sex']=='male')].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
# get a count of male 
len(data[(data['Survived']==0) & (data['Sex']=='male')])
# Out:
# 468

# %%
# get a count of female
len(data[(data['Survived']==0) & (data['Sex']=='female')])
# Out:
# 81

# %%
# get a count of female
len(data['Sex']=='female')
# Out:
# 891

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data((data['Survived']) & (data['Sex'])).value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Praveen.Rajendhiran\aimldsmonk\01 Python\.ipynb_checkpoints\Pandas.ipynb Cell 21 in <cell line: 1>()
# ...

# %%
data[data['Fare'] == min(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
# no of people 
data[data['Cabin'].isnull() == False].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   204.000000  204.000000  204.000000  185.000000  204.000000
# mean    455.401961    0.666667    1.196078   35.829297    0.441176
# std     251.379279    0.472564    0.525961   15.679356    0.628918
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     261.750000    0.000000    1.000000   24.000000    0.000000
# 50%     457.500000    1.000000    1.000000   36.000000    0.000000
# 75%     684.000000    1.000000    1.000000   48.000000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  204.000000  204.000000
# mean     0.436275   76.141504
# std      0.729976   74.391749
# min      0.000000    0.000000
# 25%      0.000000   29.453125
# 50%      0.000000   55.220850
# 75%      1.000000   89.328150
# max      4.000000  512.329200

# %%
# extract rows - iloc and loc.
data['age_Pclass'] = data['Age']+data['Pclass']

# %%
data['new_col'] = data['Name']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# delete column 
# data.drop('new_col') -- will not work as this looks at the row level by default as axis = 0
# drop does not commit to the original dataframe

data.drop('new_col', axis=1,inplace=True)

# alter option for data.drop('new_col', axis=1,inplace=True) ----> data = data.drop('new_col', axis=1)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  age_Pclass
# 0      0         A/5 21171   7.2500   NaN        S        25.0
# 1      0          PC 17599  71.2833   C85        C        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        29.0
# ...

# %% [markdown]
# # Data Manuipulation
# # Row level updates

# %%
data = data.drop(0)

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  age_Pclass
# 1      0          PC 17599  71.2833   C85        C        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        29.0
# 3      0            113803  53.1000  C123        S        36.0
# ...

# %%
# data.iloc vs loc - Internal index sequence vs Named index
# data.head shows the Named index - even though it is showing 1 -- loc, 0 is the iloc

data.iloc[0]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
data.loc[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Praveen.Rajendhiran\aimldsmonk\01 Python\.ipynb_checkpoints\Pandas.ipynb Cell 33 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Praveen.Rajendhiran/aimldsmonk/01%20Python/.ipynb_checkpoints/Pandas.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> data.loc[0]
#
# ...

# %%
data.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  age_Pclass
# 2  STON/O2. 3101282   7.9250   NaN        S        29.0
# 3            113803  53.1000  C123        S        36.0
# 4            373450   8.0500   NaN        S        38.0
# 5            330877   8.4583   NaN        Q         NaN

# %%
data.loc[101:106,['Survived','Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
data.loc[3:4,['Fare','Cabin','Embarked']]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
# if we use iloc, it does not work - why? iloc works only with default indexes; using the naming indees does not yeild the outputs
data.iloc[3:4,['Fare','Cabin','Embarked']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Praveen.Rajendhiran\aimldsmonk\01 Python\.ipynb_checkpoints\Pandas.ipynb Cell 38 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Praveen.Rajendhiran/aimldsmonk/01%20Python/.ipynb_checkpoints/Pandas.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> # if we use iloc, it does not work - why? iloc works only with default indexes; using the naming indees does not yeild the outputs
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Praveen.Rajendhiran/aimldsmonk/01%20Python/.ipynb_checkpoints/Pandas.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> data.iloc[3:4,['Fare','Cabin','Embarked']]
#
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
# ...

# %%
# if we use iloc, it does not work - why? iloc works only with default indexes; using the naming indees does not yeild the outputs
data.iloc[[3,4],[9,10,11]]
# Out:
#      Fare Cabin Embarked
# 4  8.0500   NaN        S
# 5  8.4583   NaN        Q

# %%
# if we use iloc, it does not work - why? iloc works only with default indexes; using the naming indees does not yeild the outputs
data.iloc[2:4,[9,10,11]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
#filter passeger id and pclass by column by using loc and iloc
data.loc[:,['PassengerId','Pclass']]
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
#filter passeger id and pclass by column by using loc and iloc
# selection of columns
data.iloc[:,[0,2]]
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
data.loc[[3,5],['PassengerId','Survived','Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
data.iloc[[1,3],[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 2            3         1       3
# 4            5         0       3

# %%
data[data['Age']>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# age 35 and class 3
(data['Age']=35) & (data['Pclass']=3)
# Out:
#   Input In [143]
#     (data['Age']=35) & (data['Pclass']=3)
#                 ^
# SyntaxError: invalid syntax

# %%
data1 = data.iloc[1:10,[2,3,4,5,9,10]]
data1
# Out:
#     Pclass                                               Name     Sex   Age  \
# 2        3                             Heikkinen, Miss. Laina  female  26.0
# 3        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4        3                           Allen, Mr. William Henry    male  35.0
# 5        3                                   Moran, Mr. James    male   NaN
# 6        1                            McCarthy, Mr. Timothy J    male  54.0
# 7        3                     Palsson, Master. Gosta Leonard    male   2.0
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10       3                    Sandstrom, Miss. Marguerite Rut  female   4.0
#
#        Fare Cabin
# 2    7.9250   NaN
# 3   53.1000  C123
# 4    8.0500   NaN
# 5    8.4583   NaN
# 6   51.8625   E46
# 7   21.0750   NaN
# 8   11.1333   NaN
# 9   30.0708   NaN
# 10  16.7000    G6

# %%
# try this later
data1[data1.loc == 2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Praveen.Rajendhiran\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data1.set_index('Name',inplace=True)

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
data1.dropna(axis=0)
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# McCarthy, Mr. Timothy J                            1    male  54.0  51.8625
# Sandstrom, Miss. Marguerite Rut                    3  female   4.0  16.7000
#
#                                              Cabin
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# McCarthy, Mr. Timothy J                        E46
# Sandstrom, Miss. Marguerite Rut                 G6

# %%
data1.dropna(axis=1)
# Out:
#                                                    Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                                  3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  53.1000
# Allen, Mr. William Henry                                3    male   8.0500
# Moran, Mr. James                                        3    male   8.4583
# McCarthy, Mr. Timothy J                                 1    male  51.8625
# Palsson, Master. Gosta Leonard                          3    male  21.0750
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  11.1333
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  30.0708
# Sandstrom, Miss. Marguerite Rut                         3  female  16.7000

# %% [markdown]
# # drop vs dropna - drops as is, however dropna drops NaN values.

# %%
# alteast so many non-na values are required for the threshold to operate on the dataset.
data1.dropna(axis=1,thresh=4)
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare
# Name
# Heikkinen, Miss. Laina                              7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000
# ...

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
data1.dropna(axis=0,thresh=4)
# Moran, Mr. James is removed had 4 non-na VALUES
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# Allen, Mr. William Henry                            8.0500   NaN
# ...

# %%
data1.fillna("sudh")
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male  sudh
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250  sudh
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
data1.fillna(data1['Age'].mean())
# Out:
#                                                    Pclass     Sex     Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.000
# Allen, Mr. William Henry                                3    male  35.000
# Moran, Mr. James                                        3    male  24.625
# McCarthy, Mr. Timothy J                                 1    male  54.000
# Palsson, Master. Gosta Leonard                          3    male   2.000
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.000
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.000
# Sandstrom, Miss. Marguerite Rut                         3  female   4.000
#
#                                                       Fare   Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250  24.625
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000    C123
# ...

# %%
data1.groupby('Sex').count()
# Out:
#         Pclass  Age  Fare  Cabin
# Sex
# female       5    5     5      2
# male         4    3     4      1

# %%
data1.groupby('Sex').mean()
# Out:
#         Pclass        Age      Fare
# Sex
# female     2.4  21.200000  23.78582
# male       2.5  30.333333  22.36145

# %%
data1.groupby('Sex').mean()['Age']
# Out:
# Sex
# female    21.200000
# male      30.333333
# Name: Age, dtype: float64

# %%
data1.groupby('Sex').sum()
# Out:
#         Pclass    Age      Fare
# Sex
# female      12  106.0  118.9291
# male        10   91.0   89.4458

# %%
data2 = data.iloc[0:4,0:4]

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
# horizantal and vertical merge operations
# concatenate, merge, join operations

# %%
pd.concat([data1,data2])
# Out:
#                                                    Pclass     Sex   Age  \
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
# 1                                                       1     NaN   NaN
# 2                                                       3     NaN   NaN
# 3                                                       1     NaN   NaN
# ...

# %%
#vertical
pd.concat([data1,data2],axis=1)
# Out:
#                                                    Pclass     Sex   Age  \
# Heikkinen, Miss. Laina                                3.0  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          1.0  female  35.0
# Allen, Mr. William Henry                              3.0    male  35.0
# Moran, Mr. James                                      3.0    male   NaN
# McCarthy, Mr. Timothy J                               1.0    male  54.0
# Palsson, Master. Gosta Leonard                        3.0    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     3.0  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                   2.0  female  14.0
# Sandstrom, Miss. Marguerite Rut                       3.0  female   4.0
# 1                                                     NaN     NaN   NaN
# 2                                                     NaN     NaN   NaN
# 3                                                     NaN     NaN   NaN
# ...

# %%
data1['new'] = data1 ['Pclass'].apply(lambda x:x/3)
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin       new
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123  0.333333
# ...

# %%
def fun1(x):
    return x/3

# %%
#apply function on a particular column
data1['new1'] = data1 ['Pclass'].apply(fun1)
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin       new  \
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123  0.333333
# ...

# %%
# create a new column and store length of their name

#apply function on a particular column
data2['len_name'] = data2 ['Name'].apply(len)
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  len_name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51
# 2                             Heikkinen, Miss. Laina        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)        44
# 4                           Allen, Mr. William Henry        24

# %%
#apply function on a particular column
data2['PassengerId_filter'] = data2 ['PassengerId'].apply(cust1)
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Praveen.Rajendhiran\aimldsmonk\01 Python\.ipynb_checkpoints\Pandas.ipynb Cell 73 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Praveen.Rajendhiran/aimldsmonk/01%20Python/.ipynb_checkpoints/Pandas.ipynb#Y141sZmlsZQ%3D%3D?line=0'>1</a> #apply function on a particular column
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Praveen.Rajendhiran/aimldsmonk/01%20Python/.ipynb_checkpoints/Pandas.ipynb#Y141sZmlsZQ%3D%3D?line=1'>2</a> data2['PassengerId_filter'] = data2 ['PassengerId'].apply(cust1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Praveen.Rajendhiran/aimldsmonk/01%20Python/.ipynb_checkpoints/Pandas.ipynb#Y141sZmlsZQ%3D%3D?line=2'>3</a> data2
#
# ...

# %%
def cust1(x):
    if x < 3:
        return x
    else:
        return log10(x)

# %%
def test2(x):
    if x == 'female':
        return 1
    else:
        return 0

# %%
data.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# 0 - 100 - 'A'
# 101 - 199 - 'B'
# 200+

# %%
def test3(x):
    if x <=100:
        return "A"
    elif x > 100 and x < 200:
        return "B"
    else:
        return "C"

# %%
data['Fare_group'] = data['Fare'].apply(test3)

# %%
data.groupby('Fare_group').count()
# Out:
#             PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  \
# Fare_group
# A                   837       837     837   837  837  665    837    837
# B                    33        33      33    33   33   30     33     33
# C                    20        20      20    20   20   18     20     20
#
#             Ticket  Fare  Cabin  Embarked  age_Pclass
# Fare_group
# A              837   837    161       835         665
# B               33    33     26        33          30
# C               20    20     17        20          18
